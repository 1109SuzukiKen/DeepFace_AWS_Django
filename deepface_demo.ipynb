# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
img = cv2.imread("C:\\Users\\ken19\\Pictures\\Saved Pictures\\rsyoumeisyasin.jpg")

plt.imshow(img[:,:,::-1])

plt.show()

result = DeepFace.analyze(img,actions=['emotion'])

result
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  6.37it/s]
# [{'emotion': {'angry': 2.0811419934034348,
#    'disgust': 2.432436474464339e-07,
#    'fear': 0.36546068731695414,
#    'happy': 0.30080918222665787,
#    'sad': 1.886453852057457,
#    'surprise': 0.04669690388254821,
#    'neutral': 95.31943798065186},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 71, 'y': 153, 'w': 302, 'h': 302}}]

# %%
img_plural = cv2.imread("C:\\Users\\ken19\\Pictures\\Saved Pictures\\S__40026119.jpg")

plt.imshow(img_plural[:,:,::-1])

plt.show()

result = DeepFace.analyze(img_plural,actions=['emotion'])

result
# Out:
# ...
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 10.54it/s]
# [{'emotion': {'angry': 0.04046795074827969,
#    'disgust': 1.7532767060401966e-05,
#    'fear': 0.5986644420772791,
#    'happy': 0.007004304643487558,
#    'sad': 96.99174165725708,
#    'surprise': 6.37226227340193e-07,
#    'neutral': 2.3621078580617905},
#   'dominant_emotion': 'sad',
#   'region': {'x': 187, 'y': 527, 'w': 67, 'h': 67}},
#  {'emotion': {'angry': 1.8963102251291275,
#    'disgust': 2.9993957317842046e-08,
#    'fear': 2.1443212404847145,
#    'happy': 0.0014643584108853247,
#    'sad': 38.84986937046051,
#    'surprise': 0.022244261344894767,
#    'neutral': 57.08578824996948},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 343, 'y': 626, 'w': 254, 'h': 254}},
#  {'emotion': {'angry': 36.13584637641907,
#    'disgust': 0.22051334381103516,
#    'fear': 32.820600271224976,
#    'happy': 0.020548849715851247,
#    'sad': 26.505577564239502,
#    'surprise': 0.32465162221342325,
# ...

# %%
type(result)
# Out:
# list

# %%
result[1]["region"]["x"]
# Out:
# 343

# %%
trim = []
for i in range(len(result)):
    result[i]["region"]["x"]

# %% [markdown]
# 感情。年齢。女性。
# djangoをAWSで実装
